# %%
import numpy as np

# %%
import csv

# %%
to_save_dir = '../../dgl/apps/kg/data/wiki/'

# %%
raw_dir = '../data/raw/'

# %%
# !head ../data/raw/wikidata_20190805.qpq_item_statements.csv
# Out:
# source_item_id,edge_property_id,target_item_id,el_rank
# 31,1344,1088364,1
# 31,1151,3247091,1
# 31,1546,1308013,1
# 31,5125,7112200,1
# 31,38,4916,0
# 31,38,232415,1
# 31,1792,7021332,1
# 31,2852,1061257,1
# 31,2852,25648793,1

# %%
entity_input_file = raw_dir + 'wikidata_20190805.item.csv'
entity_output_file = to_save_dir + 'entities.dict'
entity_keep_cols = [0, 3]
entity_text_format = "{}\t{}\n"
entity_skip_lines = 1
entity_dict = {}

# %%
edge_input_file = raw_dir + 'wikidata_20190805.property.csv'
edge_output_file = to_save_dir + 'relations.dict'
edge_keep_cols = [0, 1]
edge_text_format = "{}\t{}\n"
edge_skip_lines = 1 
edge_dict = {}

# %%
def write_to_file_with_format(input_file, output_file, keep_cols, text_format, skip_lines = 0):
    m = len(keep_cols)
    with open(input_file, 'r') as file_inp, open(output_file, 'w') as file_out:
        inp = csv.reader(file_inp)
        for _ in range(skip_lines):
            next(inp)
        for l in inp:
            to_write = [l[col] for col in keep_cols if l[col]]
            if len(to_write) < m:
                continue
            #file_out.write(text_format.format(*to_write))

# %%
def write_to_file_with_format_and_dict(input_file, output_file, keep_cols, text_format, skip_lines = 0, dictionary = None):
    m = len(keep_cols)
    
    i = 0
    #mapping_dict = {}
    with open(input_file, 'r') as file_inp, open(output_file, 'w') as file_out:
        inp = csv.reader(file_inp)
        for _ in range(skip_lines):
            next(inp)
        for l in inp:
            to_write = [l[col] for col in keep_cols if l[col]]
            original_key = int(to_write[0])
            to_write[0] = i
            if len(to_write) < m:
                continue
            #mapping_dict[original_key] = i
            i += 1
            #file_out.write(text_format.format(*to_write))
            dictionary[original_key] = to_write[1]
    #return mapping_dict

# %%
# write_to_file_with_format(
#     input_file=edge_input_file,
#     output_file=edge_output_file,
#     keep_cols=edge_keep_cols,
#     text_format=edge_text_format,
#     skip_lines=edge_skip_lines,
# )

edge_mapping_dict = write_to_file_with_format_and_dict(
    input_file=edge_input_file,
    output_file=edge_output_file,
    keep_cols=edge_keep_cols,
    text_format=edge_text_format,
    skip_lines=edge_skip_lines,
    dictionary=edge_dict,
)

# %%
# write_to_file_with_format(
#     input_file=entity_input_file,
#     output_file=entity_output_file,
#     keep_cols=entity_keep_cols,
#     text_format=entity_text_format,
#     skip_lines=entity_skip_lines,
# )

entity_mapping_dict = write_to_file_with_format_and_dict(
    input_file=entity_input_file,
    output_file=entity_output_file,
    keep_cols=entity_keep_cols,
    text_format=entity_text_format,
    skip_lines=entity_skip_lines,
    dictionary=entity_dict,
)

# %%
len(entity_dict)
# Out:
# 8059838

# %%
len(edge_dict)
# Out:
# 6490

# %%
def write_to_file_with_format_for_triplet(input_file, output_file, output_file2, output_file3, text_format,\
                                          skip_lines = 0, triplet_head_idx = 0, triplet_tail_idx = 2, \
                                         triplet_edge_idx = 1):
    with open(input_file, 'r') as file_inp, open(output_file, 'w') as file_out,\
    open(output_file2, 'w') as file_out2, open(output_file3, 'w') as file_out3:
        
        final_ent_dict = {}
        final_rel_dict = {}
        inp = csv.reader(file_inp)
        for _ in range(skip_lines):
            next(inp)
        for l in inp:
            to_write = []
            triplet_head, triplet_edge, triplet_tail = \
            int(l[triplet_head_idx]), int(l[triplet_edge_idx]), int(l[triplet_tail_idx])
#             if not triplet_head in entity_mapping_dict or not triplet_tail in entity_mapping_dict or \
#             not triplet_edge in edge_mapping_dict:
            if not triplet_head in entity_dict or not triplet_tail in entity_dict or \
            not triplet_edge in edge_dict:
                continue
            rand_int = np.random.randint(200)
            if rand_int > 1:
                write_file_out = file_out
            elif rand_int == 0:
                write_file_out = file_out2
            else:
                write_file_out = file_out3
            write_file_out.write(text_format.format(entity_dict[triplet_head], edge_dict[triplet_edge], entity_dict[triplet_tail]))
            
#             final_ent_dict[entity_mapping_dict[triplet_head]] = entity_dict[triplet_head]
#             final_ent_dict[entity_mapping_dict[triplet_tail]] = entity_dict[triplet_tail]
#             final_rel_dict[edge_mapping_dict[triplet_edge]] = edge_dict[triplet_edge]
            final_ent_dict[triplet_head] = entity_dict[triplet_head]
            final_ent_dict[triplet_tail] = entity_dict[triplet_tail]
            final_rel_dict[triplet_edge] = edge_dict[triplet_edge]
        return final_ent_dict, final_rel_dict

# %%
triplet_input_file = raw_dir + 'wikidata_20190805.qpq_item_statements.csv'
triplet_output_file = to_save_dir + 'train.txt'
triplet_output_file_2 = to_save_dir + 'valid.txt'
triplet_output_file_3 = to_save_dir + 'test.txt'
triplet_text_format = "{}\t{}\t{}\n"
triplet_skip_lines = 1

# %%
final_ent_dict, final_rel_dict = write_to_file_with_format_for_triplet(
    input_file=triplet_input_file,
    output_file=triplet_output_file,
    output_file2=triplet_output_file_2,
    output_file3=triplet_output_file_3,
    text_format=triplet_text_format,
    skip_lines=triplet_skip_lines,
)

# %%
max(final_ent_dict)
# Out:
# 66205545

# %%
len(final_ent_dict)
# Out:
# 7626789

# %%
with open(edge_output_file, 'w') as file_out:
    final_rel_mapping = {}
    for i, (key, val) in enumerate(final_rel_dict.items()):
        final_rel_mapping[i] = key
        file_out.write("{}\t{}\n".format(i, val))

# %%
with open(entity_output_file, 'w') as file_out:
    final_ent_mapping = {}
    for i, (key, val) in enumerate(final_ent_dict.items()):
        final_ent_mapping[i] = key
        file_out.write("{}\t{}\n".format(i, val))

# %%
final_ent_mapping
# Out:
# {0: 1,
#  1: 323,
#  2: 837317,
#  3: 1208634,
#  4: 1079826,
#  5: 273508,
#  6: 1079806,
#  7: 3491753,
#  8: 5551050,
#  9: 133327,
#  10: 221392,
#  11: 6999,
#  12: 18343,
#  13: 79925,
#  14: 2504088,
#  15: 185674,
#  16: 5457948,
#  17: 136407,
#  18: 11412,
#  19: 1133705,
#  20: 497745,
#  21: 1139177,
#  22: 7439451,
#  23: 15241043,
#  673: 1264097,
#  674: 1076709,
#  675: 528356,
#  676: 740863,
#  677: 948596,
#  678: 1000088,
#  679: 1185437,
#  680: 766942,
#  681: 1000090,
#  682: 378958,
#  683: 1191537,
#  684: 658073,
#  685: 837046,
#  686: 852767,
#  687: 11399,
#  688: 193355,
#  689: 83270,
#  690: 499028,
#  691: 1000091,
#  692: 240419,
#  693: 1852771,
#  694: 782612,
#  695: 954615,
#  696: 339404,
#  697: 2498463,
#  698: 2702233,
#  699: 1019344,
#  700: 742932,
#  701: 2038595,
#  702: 772784,
#  703: 1822977,
#  704: 2238211,
#  705: 13360693,
#  706: 1000092,
#  707: 1000093,
#  708: 17460872,
#  709: 17460865,
#  710: 1000094,
#  711: 11424,
#  712: 215017,
#  713: 200405,
#  714: 717663,
#  715: 145,
#  716: 2484376,
#  717: 157443,
#  718: 1000096,
#  719: 1000097,
#  720: 628280,
#  721: 1194517,
#  722: 1117037,
#  723: 907946,
#  724: 523469,
#  725: 2097168,
#  726: 647921,
#  727: 739434,
#  728: 1000098,
#  729: 1000099,
#  730: 244517,
#  731: 25193902,
#  732: 10001,
#  733: 3912,
#  734: 83324,
#  735: 773,
#  736: 707813,
#  737: 8375692,
#  738: 217818,
#  739: 10020,
#  740: 2905573,
#  741: 810795,
#  742: 8732234,
#  743: 1000100,
#  744: 1000101,
#  745: 792883,
#  746: 2720386,
#  747: 2242156,
#  748: 2720383,
#  749: 2626478,
#  750: 781177,
#  751: 1983708,
#  752: 1873880,
#  753: 2219278,
#  754: 2219174,
#  755: 950804,
#  756: 2656698,
#  757: 8752822,
#  758: 1000102,
#  759: 1000103,
#  760: 115148,
#  761: 498162,
#  762: 1000104,
#  763: 618779,
#  764: 647687,
#  765: 2790989,
#  766: 1000105,
#  767: 115200,
#  768: 751708,
#  769: 5390,
#  770: 5762,
#  771: 1000106,
#  772: 12140,
#  773: 1000107,
#  774: 2983893,
#  775: 1021711,
#  776: 36600,
#  777: 1693,
#  778: 1000108,
#  779: 849640,
#  780: 1000109,
#  781: 33,
#  782: 856076,
#  783: 5697,
#  784: 5980,
#  785: 6723,
#  786: 6760,
#  787: 8994741,
#  788: 5061084,
#  789: 1412,
#  790: 100011,
#  791: 39,
#  792: 1000112,
#  793: 488924,
#  794: 1000113,
#  795: 5698,
#  796: 204382,
#  797: 1000114,
#  798: 1000115,
#  799: 11131,
#  800: 3957,
#  801: 1115575,
#  802: 652559,
#  803: 41502238,
#  804: 1000116,
#  805: 179692,
#  806: 1000117,
#  807: 6344936,
#  808: 5693,
#  809: 7934261,
#  810: 18691231,
#  811: 1000119,
#  812: 5709,
#  813: 780914,
#  814: 6338533,
#  815: 285894,
#  816: 100012,
#  817: 72,
#  818: 11943,
#  819: 24609,
#  820: 193199,
#  821: 682070,
#  822: 1053678,
#  823: 1000120,
#  824: 6543832,
#  825: 12510,
#  826: 181296,
#  827: 1000121,
#  828: 5703,
#  829: 6337386,
#  830: 8746063,
#  831: 18691405,
#  832: 1000123,
#  833: 3224,
#  834: 820679,
#  835: 5355087,
#  836: 2973799,
#  837: 408,
#  838: 1000124,
#  839: 46118,
#  840: 42392,
#  841: 1000125,
#  842: 1131296,
#  843: 426945,
#  844: 1000127,
#  845: 1000128,
#  846: 3305213,
#  847: 483992,
#  848: 189458,
#  849: 1047337,
#  850: 3031,
#  851: 204776,
#  852: 1144593,
#  853: 1471,
#  854: 2981,
#  855: 90,
#  856: 193472,
#  857: 148993,
#  858: 808132,
#  859: 200539,
#  860: 3354532,
#  861: 1922956,
#  862: 8060,
#  863: 8355,
#  864: 204948,
#  865: 639669,
#  866: 16518,
#  867: 12280,
#  868: 14130,
#  869: 163025,
#  870: 190063,
#  871: 2073308,
#  872: 527,
#  873: 6578319,
#  874: 194189,
#  875: 296955,
#  876: 4259259,
#  877: 1700481,
#  878: 768717,
#  879: 10294,
#  880: 19652,
#  881: 1000129,
#  882: 732986,
#  883: 12813115,
#  884: 34,
#  885: 503180,
#  886: 100013,
#  887: 15711008,
#  888: 99969,
#  889: 100407,
#  890: 101551,
#  891: 101569,
#  892: 99966,
#  893: 101812,
#  894: 100137,
#  895: 101135,
#  896: 101554,
#  897: 101693,
#  898: 1134686,
#  899: 193937,
#  900: 1000130,
#  901: 13406463,
#  902: 5297,
#  903: 1000132,
#  904: 3093,
#  905: 110574,
#  906: 700965,
#  907: 864290,
#  908: 244584,
#  909: 732148,
#  910: 869737,
#  911: 869959,
#  912: 656420,
#  913: 1000133,
#  914: 35715,
#  915: 591459,
#  916: 5355986,
#  917: 2973634,
#  918: 25011920,
#  919: 1000135,
#  920: 58401,
#  921: 696242,
#  922: 704714,
#  923: 21208,
#  924: 6540107,
#  925: 8044529,
#  926: 6191946,
#  927: 10908947,
#  928: 378048,
#  929: 5521207,
#  930: 7267965,
#  931: 6963373,
#  932: 8070473,
#  933: 8069074,
#  934: 5071555,
#  935: 8044407,
#  936: 6203426,
#  937: 1070990,
#  938: 22704398,
#  939: 22704397,
#  940: 1000136,
#  941: 7976709,
#  942: 6346,
#  943: 1000137,
#  944: 582940,
#  945: 701410,
#  946: 849283,
#  947: 846930,
#  948: 870067,
#  949: 846117,
#  950: 1000138,
#  951: 12526,
#  952: 274884,
#  953: 187638,
#  954: 715912,
#  955: 181535,
#  956: 715902,
#  957: 185402,
#  958: 1004486,
#  959: 187691,
#  960: 27922737,
#  961: 1000139,
#  962: 262,
#  963: 1349255,
#  964: 2989398,
#  965: 14954476,
#  966: 3019536,
#  967: 1000140,
#  968: 881,
#  969: 1070942,
#  970: 19610511,
#  971: 5119,
#  972: 36446,
#  973: 1000141,
#  974: 162785,
#  975: 702745,
#  976: 843094,
#  977: 847483,
#  978: 850231,
#  979: 538921,
#  980: 856170,
#  981: 1000142,
#  982: 42956,
#  983: 19206,
#  984: 516223,
#  985: 5361067,
#  986: 11059841,
#  987: 1065118,
#  988: 1000143,
#  989: 717,
#  990: 1042713,
#  991: 515,
#  992: 1000144,
#  993: 554601,
#  994: 1000146,
#  995: 553343,
#  996: 1000147,
#  997: 554553,
#  998: 1000148,
#  999: 489935,
#  ...}

# %%
import pickle

# %%
folder = '../../AC297r_2019_Kensho/data/knowledge_graph_data/'

# %%
def write_dict_to_pickle(file, dictionary):
    with open(file, 'wb') as handle:
        pickle.dump(dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
file_rel = folder + 'idx2id_edge_full.pickle'
write_dict_to_pickle(file_rel, final_rel_mapping)

# %%
file_ent = folder + 'idx2id_entity_full.pickle'
write_dict_to_pickle(file_ent, final_ent_mapping)

# %%
file_rel_text = folder + 'id2text_edge_full.pickle'
write_dict_to_pickle(file_rel_text, final_rel_dict)

# %%
file_ent_text = folder + 'id2text_entity_full.pickle'
write_dict_to_pickle(file_ent_text, final_ent_dict)

# %%
with open(file_rel_text, 'rb') as f:
    a = pickle.load(f)

# %%
a
# Out:
# {793: 'significant event',
#  910: "topic's main category",
#  527: 'has part',
#  2670: 'has parts of the class',
#  1419: 'shape',
#  2184: 'history of topic',
#  1552: 'has quality',
#  398: 'child astronomical body',
#  1343: 'described by source',
#  828: 'has cause',
#  1889: 'different from',
#  2579: 'studied by',
#  279: 'subclass of',
#  17: 'country',
#  131: 'located in the administrative territorial entity',
#  163: 'flag',
#  194: 'legislative body',
#  190: 'twinned administrative body',
#  138: 'named after',
#  1792: 'category of associated people',
#  421: 'located in time zone',
#  1376: 'capital of',
#  112: 'founded by',
#  6: 'head of government',
#  206: 'located in or next to body of water',
#  47: 'shares border with',
#  361: 'part of',
#  5125: 'Wikimedia outline',
#  1791: 'category of people buried here',
#  1313: 'office held by head of government',
#  1830: 'owner of',
#  706: 'located on terrain feature',
#  30: 'continent',
#  610: 'highest point',
#  1589: 'lowest point',
#  31: 'instance of',
#  35: 'head of state',
#  37: 'official language',
#  38: 'currency',
#  78: 'top-level Internet domain',
#  85: 'anthem',
#  36: 'capital',
#  150: 'contains administrative territorial entity',
#  463: 'member of',
#  237: 'coat of arms',
#  1465: 'category for people who died here',
#  1740: 'category for films shot at this location',
#  1151: "topic's main Wikimedia portal",
#  530: 'diplomatic relation',
#  2633: 'geography of topic',
#  2853: 'electrical plug type',
#  2936: 'language used',
#  127: 'owned by',
#  407: 'language of work or name',
#  275: 'license',
#  1056: 'product or material produced',
#  137: 'operator',
#  282: 'writing system',
#  175: 'performer',
#  264: 'record label',
#  155: 'follows',
#  136: 'genre',
#  437: 'distribution format',
#  156: 'followed by',
#  119: 'place of burial',
#  106: 'occupation',
#  19: 'place of birth',
#  20: 'place of death',
#  27: 'country of citizenship',
#  735: 'given name',
#  172: 'ethnic group',
#  1412: 'languages spoken, written or signed',
#  166: 'award received',
#  176: 'manufacturer',
#  516: 'powered by',
#  1716: 'brand',
#  105: 'taxon rank',
#  171: 'parent taxon',
#  931: 'place served by transport hub',
#  641: 'sport',
#  118: 'league',
#  272: 'production company',
#  161: 'cast member',
#  495: 'country of origin',
#  364: 'original language of film or TV show',
#  6885: 'historical region',
#  376: 'located on astronomical location',
#  140: 'religion',
#  708: 'diocese',
#  800: 'notable work',
#  102: 'member of political party',
#  1196: 'manner of death',
#  2632: 'place of detention',
#  69: 'educated at',
#  734: 'family name',
#  509: 'cause of death',
#  39: 'position held',
#  551: 'residence',
#  937: 'work location',
#  108: 'employer',
#  103: 'native language',
#  1416: 'affiliation',
#  91: 'sexual orientation',
#  241: 'military branch',
#  410: 'military rank',
#  460: 'said to be the same as',
#  159: 'headquarters location',
#  1454: 'legal form',
#  84: 'architect',
#  276: 'location',
#  1366: 'replaced by',
#  162: 'producer',
#  86: 'composer',
#  1383: 'contains settlement',
#  1027: 'conferred by',
#  1064: 'track gauge',
#  559: 'terminus',
#  170: 'creator',
#  135: 'movement',
#  180: 'depicts',
#  186: 'material used',
#  195: 'collection',
#  921: 'main subject',
#  6216: 'copyright status',
#  360: 'is a list of',
#  3450: 'sports season of league or competition',
#  289: 'vessel class',
#  50: 'author',
#  87: 'librettist',
#  676: 'lyrics by',
#  403: 'mouth of the watercourse',
#  4614: 'drainage basin',
#  179: 'part of the series',
#  1346: 'winner',
#  58: 'screenwriter',
#  462: 'color',
#  1389: 'product certification',
#  1071: 'location of final assembly',
#  413: 'position played on team / speciality',
#  54: 'member of sports team',
#  1875: 'represented by',
#  802: 'student',
#  6275: 'copyright representative',
#  6379: 'has works in the collection',
#  6886: 'writing language',
#  1427: 'start point',
#  1444: 'destination point',
#  66: 'ancestral home',
#  1424: "topic's main template",
#  1344: 'participant of',
#  1990: 'species kept',
#  287: 'designed by',
#  178: 'developer',
#  141: 'IUCN conservation status',
#  1532: 'country for sport',
#  4552: 'mountain range',
#  1001: 'applies to jurisdiction',
#  97: 'noble title',
#  358: 'discography',
#  40: 'child',
#  1303: 'instrument',
#  461: 'opposite of',
#  57: 'director',
#  344: 'director of photography',
#  750: 'distributor',
#  417: 'patron saint',
#  404: 'game mode',
#  400: 'platform',
#  123: 'publisher',
#  479: 'input method',
#  169: 'chief executive officer',
#  749: 'parent organization',
#  452: 'industry',
#  1269: 'facet of',
#  306: 'operating system',
#  1050: 'medical condition',
#  2360: 'intended public',
#  26: 'spouse',
#  611: 'religious order',
#  647: 'drafted by',
#  81: 'connecting line',
#  197: 'adjacent station',
#  2094: 'competition class',
#  2522: 'victory',
#  3967: 'final event',
#  22: 'father',
#  3373: 'sibling',
#  710: 'participant',
#  1435: 'heritage designation',
#  25: 'mother',
#  53: 'family',
#  1411: 'nominated for',
#  607: 'conflict',
#  1399: 'convicted of',
#  144: 'based on',
#  974: 'tributary',
#  736: 'cover art by',
#  870: 'instrumentation',
#  1598: 'consecrator',
#  1431: 'executive producer',
#  840: 'narrative location',
#  1142: 'political ideology',
#  6365: 'member category',
#  1754: 'category related to list',
#  4794: 'season starts',
#  2348: 'time period',
#  184: 'doctoral advisor',
#  185: 'doctoral student',
#  674: 'characters',
#  2578: 'studies',
#  183: 'endemic to',
#  157: 'killed by',
#  1576: 'lifestyle',
#  511: 'honorific prefix',
#  737: 'influenced by',
#  1066: 'student of',
#  101: 'field of work',
#  1441: 'present in work',
#  2341: 'indigenous to',
#  4913: 'dialect of',
#  366: 'use',
#  113: 'airline hub',
#  121: 'item operated',
#  149: 'architectural style',
#  205: 'basin country',
#  740: 'location of formation',
#  1464: 'category for people born here',
#  1000: 'record held',
#  7084: 'related category',
#  286: 'head coach',
#  1037: 'director/manager',
#  291: 'place of publication',
#  3912: 'newspaper format',
#  1049: 'worshipped by',
#  61: 'discoverer or inventor',
#  3022: 'flag bearer',
#  466: 'occupant',
#  930: 'type of electrification',
#  3858: 'route diagram',
#  1308: 'officeholder',
#  748: 'appointed by',
#  2098: 'substitute/deputy/replacement of office/officeholder',
#  915: 'filming location',
#  414: 'stock exchange',
#  21: 'sex or gender',
#  1038: 'relative',
#  3018: 'located in protected area',
#  945: 'allegiance',
#  412: 'voice type',
#  552: 'handedness',
#  1432: 'B-side (DEPRECATED)',
#  1995: 'health specialty',
#  1365: 'replaces',
#  5025: 'gens',
#  2515: 'costume designer',
#  115: 'home venue',
#  1750: 'name day',
#  1533: 'family name identical to this given name',
#  523: 'temporal range start',
#  524: 'temporal range end',
#  1877: 'after a work by',
#  355: 'subsidiary',
#  488: 'chairperson',
#  2416: 'sports discipline competed in',
#  1040: 'film editor',
#  2408: 'set in period',
#  2868: 'subject has role',
#  2175: 'medical condition treated',
#  3602: 'candidacy in election',
#  2283: 'uses',
#  2554: 'production designer',
#  2061: 'aspect ratio',
#  449: 'original network',
#  725: 'voice actor',
#  512: 'academic degree',
#  541: 'office contested',
#  4908: 'season',
#  451: 'partner',
#  739: 'ammunition',
#  1080: 'from fictional universe',
#  4878: 'symbolizes',
#  277: 'programming language',
#  3966: 'programming paradigm',
#  485: 'archives at',
#  59: 'constellation',
#  5135: 'greater than',
#  467: 'legislated by',
#  1891: 'signatory',
#  618: 'source of energy',
#  3679: 'stock market index',
#  1950: 'second family name in Spanish name',
#  88: 'commissioned by',
#  2596: 'culture',
#  562: 'central bank/issuer',
#  1542: 'has effect',
#  2597: 'Gram staining',
#  797: 'authority',
#  177: 'crosses',
#  598: 'commander of',
#  98: 'editor',
#  4969: 'derivative work',
#  3095: 'practiced by',
#  110: 'illustrator',
#  483: 'recorded at',
#  5008: 'on focus list of Wikimedia project',
#  501: 'enclave within',
#  1811: 'list of episodes',
#  767: 'contributor(s) to the creative work or subject',
#  1535: 'used by',
#  2962: 'title of chess person',
#  2176: 'drug used for treatment',
#  624: 'guidance system',
#  2975: 'host',
#  1290: 'godparent',
#  2852: 'emergency phone number',
#  1304: 'central bank',
#  1906: 'office held by head of state',
#  803: 'professorship',
#  4791: 'commanded by',
#  1336: 'territory claimed by',
#  2978: 'wheel arrangement',
#  500: 'exclave of',
#  248: 'stated in',
#  111: 'measured physical quantity',
#  16: 'highway system',
#  669: 'located on street',
#  5606: 'station category',
#  1433: 'published in',
#  944: 'Code of nomenclature',
#  2650: 'interested in',
#  1568: 'domain',
#  664: 'organizer',
#  3876: 'category for alumni of educational institution',
#  991: 'successful candidate',
#  126: 'maintained by',
#  859: 'sponsor',
#  1654: 'wing configuration',
#  1414: 'GUI toolkit or framework',
#  1560: 'given name version for other gender',
#  1884: 'hair color',
#  4000: 'has fruit type',
#  2746: 'production statistics',
#  3716: 'social classification',
#  726: 'candidate',
#  941: 'inspired by',
#  208: 'executive body',
#  2789: 'connects with',
#  3320: 'board member',
#  3712: 'objective of project or action',
#  375: 'space launch vehicle',
#  6087: 'coach of sports team',
#  837: 'day in year for periodic occurrence',
#  841: 'feast day',
#  2695: 'type locality (geology)',
#  556: 'crystal system',
#  1640: 'curator',
#  2438: 'narrator',
#  469: 'lakes on river',
#  201: 'lake outflow',
#  411: 'canonization status',
#  826: 'tonality',
#  122: 'basic form of government',
#  832: 'public holiday',
#  868: 'foods traditionally associated',
#  2517: 'category for recipients of this award',
#  1321: 'place of origin (Switzerland)',
#  812: 'academic major',
#  658: 'tracklist',
#  741: 'playing hand',
#  200: 'lake inflows',
#  371: 'presenter',
#  4345: 'excavation director',
#  4132: 'linguistic typology',
#  2358: 'Roman praenomen',
#  2354: 'has list',
#  1018: 'language regulatory body',
#  1547: 'depends on software',
#  1073: 'writable file format',
#  1072: 'readable file format',
#  2851: 'payment types accepted',
#  427: 'taxonomic type',
#  2564: 'Köppen climate classification',
#  189: 'location of discovery',
#  408: 'software engine',
#  1885: 'cathedral',
#  1462: 'standards body',
#  425: 'field of this occupation',
#  3113: 'does not have part',
#  1268: 'represents',
#  3096: 'KML file',
#  504: 'home port',
#  517: 'interaction',
#  2152: 'antiparticle',
#  2079: 'fabrication method',
#  3137: 'parent peak',
#  521: 'scheduled service destination',
#  3931: 'copyright holder',
#  833: 'interchange station',
#  532: 'port of registry',
#  193: 'main building contractor',
#  1923: 'participating team',
#  3279: 'statistical leader',
#  825: 'dedicated to',
#  1299: 'depicted by',
#  4195: 'category for employees of the organization',
#  5800: 'narrative role',
#  1840: 'investigated by',
#  5996: 'category for films in this language',
#  783: 'hymenium type',
#  788: 'mushroom ecological type',
#  787: 'spore print color',
#  789: 'edibility',
#  5138: 'season of club or team',
#  5249: 'sports competition competed at',
#  609: 'terminus location',
#  2505: 'carries',
#  2568: 'repealed by',
#  6112: 'category for members of a team',
#  6364: 'official color',
#  450: 'astronaut mission',
#  534: 'streak color',
#  927: 'anatomical location',
#  1582: 'natural product of taxon',
#  3729: 'next lower rank',
#  912: 'has facility',
#  634: 'captain',
#  553: 'website account on',
#  3938: 'named by',
#  1387: 'political alignment',
#  2673: 'next crossing upstream',
#  3842: 'located in present-day administrative territorial entity',
#  114: 'airline alliance',
#  4446: 'reward program',
#  4428: 'implementation of',
#  1434: 'takes place in fictional universe',
#  2541: 'operating area',
#  1382: 'partially coincident with',
#  406: 'soundtrack release',
#  65: 'site of astronomical discovery',
#  703: 'found in taxon',
#  196: 'minor planet group',
#  397: 'parent astronomical body',
#  1408: 'licensed to broadcast to',
#  3403: 'coextensive with',
#  1327: 'partner in business or sport',
#  1637: 'undercarriage',
#  547: 'commemorates',
#  520: 'armament',
#  770: 'cause of destruction',
#  1283: 'filmography',
#  2894: 'day of week',
#  1347: 'military casualty classification',
#  2388: 'office held by head of the organization',
#  4628: 'ICTV virus genome composition',
#  1028: 'donated by',
#  533: 'target',
#  631: 'structural engineer',
#  2974: 'habitat',
#  765: 'surface played on',
#  2922: 'month of the year',
#  505: 'general manager',
#  1672: 'this taxon is source of',
#  3815: 'volcano observatory',
#  2992: 'software quality assurance',
#  3730: 'next higher rank',
#  4330: 'contains',
#  689: 'afflicts',
#  5607: 'located in the ecclesiastical territorial entity',
#  2827: 'flower color',
#  3342: 'significant person',
#  5389: 'permanent resident of',
#  4647: 'location of first performance',
#  4792: 'dam',
#  3975: 'secretary general',
#  4151: 'game mechanics',
#  881: 'type of variable star',
#  5940: 'plot expanded in',
#  2512: 'series spin-off',
#  1192: 'connecting service',
#  805: 'statement is subject of',
#  2770: 'source of income',
#  2674: 'next crossing downstream',
#  807: 'separated from',
#  707: 'satellite bus',
#  522: 'type of orbit',
#  2925: 'domain of saint or deity',
#  129: 'physically interacts with',
#  885: 'origin of the watercourse',
#  972: 'catalog',
#  167: 'structure replaced by',
#  5056: 'patronym or matronym for this person',
#  2462: 'member of the deme',
#  2567: 'amended by',
#  6338: 'colorist',
#  5460: 'grants',
#  1420: 'taxon synonym',
#  2286: 'arterial supply',
#  2289: 'venous drainage',
#  2288: 'lymphatic drainage',
#  2389: 'organization directed from the office or person',
#  3032: 'adjacent building',
#  3085: 'qualifies for event',
#  1075: 'rector',
#  5096: 'member of the crew of',
#  2384: 'statement describes',
#  4312: 'camera setup',
#  2376: 'superpartner of',
#  943: 'programmer',
#  1200: 'bodies of water basin category',
#  1876: 'vessel',
#  780: 'symptoms',
#  3301: 'broadcast by',
#  3989: 'members have occupation',
#  3438: 'vehicle normally used',
#  1074: 'fictional analog of',
#  1002: 'engine configuration',
#  1046: 'discovery method',
#  4586: 'type foundry',
#  567: 'underlies',
#  568: 'overlies',
#  418: 'seal description',
#  2563: 'superhuman feature or ability',
#  1773: 'attributed to',
#  2499: 'league level above',
#  2500: 'league level below',
#  880: 'CPU',
#  2378: 'issued by',
#  3300: 'musical conductor',
#  3264: 'radix',
#  3803: 'original film format',
#  4426: 'Y-DNA Haplogroup',
#  1029: 'crew member',
#  769: 'significant drug interaction',
#  1881: 'list of characters',
#  3764: 'pole position',
#  5053: 'fastest lap',
#  2375: 'has superpartner',
#  1312: 'has facet polytope',
#  924: 'possible treatment',
#  1924: 'vaccine for',
#  3150: 'birthday',
#  1034: 'main food source',
#  3828: 'wears',
#  7047: 'enemy of',
#  1302: 'primary destinations',
#  3091: 'mount',
#  6758: 'supported sports team',
#  1625: 'has melody',
#  1652: 'referee',
#  1363: 'points/goal scored by',
#  6104: 'maintained by WikiProject',
#  2882: 'relegated',
#  4043: 'emulates',
#  1731: 'Fach',
#  1202: 'carries scientific instrument',
#  2321: 'general classification of race participants',
#  4323: 'young rider classification',
#  3494: 'points classification',
#  4320: 'mountains classification',
#  3497: 'teams classification by time',
#  5236: 'prime factor',
#  4743: 'animal breed',
#  1479: 'has contributing factor',
#  4675: 'appears in the form of',
#  4584: 'first appearance',
#  5769: 'editor-in-chief',
#  747: 'has edition',
#  4149: 'conjugate base',
#  2869: 'record or record progression',
#  5869: 'model item',
#  263: 'official residence',
#  4884: 'court',
#  7045: 'chassis',
#  199: 'business division',
#  1809: 'choreographer',
#  2575: 'measures',
#  3075: 'official religion',
#  3501: 'Catholic rite',
#  1264: 'valid in period',
#  2058: 'depositor',
#  2813: 'mouthpiece',
#  822: 'mascot',
#  2159: 'solves',
#  2012: 'cuisine',
#  1322: 'dual to',
#  1880: 'measured by',
#  655: 'translator',
#  3461: 'designated as terrorist by',
#  1318: 'proved by',
#  1557: 'manifestation of',
#  3092: 'film crew member',
#  2647: 'source of material',
#  3490: 'muscle origin',
#  3491: 'muscle insertion',
#  3189: 'innervated by',
#  3080: 'game artist',
#  3174: 'art director',
#  3173: 'offers view on',
#  2700: 'protocol',
#  5805: 'OSI Model layer location',
#  2291: 'charted in',
#  4810: 'reads environment variable',
#  790: 'approved by',
#  1403: 'original combination',
#  1165: 'home world',
#  744: 'asteroid family',
#  1158: 'location of landing',
#  629: 'edition or translation of',
#  588: 'coolant',
#  3033: 'package management system',
#  3919: 'contributed to creative work',
#  542: 'officially opened by',
#  1136: 'solved by',
#  720: 'asteroid spectral type',
#  2551: 'used metre',
#  5826: 'majority opinion by',
#  5642: 'risk factor',
#  5995: 'kit supplier',
#  1596: 'penalty',
#  1605: 'has natural reservoir',
#  2293: 'genetic association',
#  1678: 'has vertex figure',
#  831: 'parent club',
#  834: 'train depot',
#  92: 'main regulatory text',
#  1656: 'unveiled by',
#  209: 'highest judicial authority',
#  823: 'speaker',
#  942: 'theme music',
#  4599: 'monomer of',
#  3833: 'diaspora',
#  913: 'notation',
#  457: 'foundational text',
#  1068: 'instruction set',
#  2652: 'partnership with',
#  3512: 'means of locomotion',
#  560: 'direction',
#  3701: 'incarnation of',
#  1478: 'has immediate cause',
#  1455: 'list of works',
#  1032: 'Digital Rights Management system',
#  6872: 'has written for',
#  4101: 'dissertation submitted to',
#  1406: 'script directionality',
#  2155: 'solid solution series with',
#  608: 'exhibition history',
#  2634: 'sitter',
#  2849: 'produced by',
#  2329: 'antagonist muscle',
#  923: 'medical examinations',
#  1035: 'honorific suffix',
#  2860: 'cites',
#  3259: 'intangible cultural heritage status',
#  3263: 'base',
#  2937: 'parliamentary term',
#  6477: 'does not have quality',
#  6291: 'advertises',
#  6948: 'video system',
#  1456: 'list of monuments',
#  2095: 'co-driver',
#  3179: 'territory overlaps',
#  4661: 'reservoir created',
#  2591: 'grammatical option indicates',
#  4733: 'produced sound',
#  4843: 'development of anatomical structure',
#  5353: 'school district',
#  3448: 'stepparent',
#  3415: 'start period',
#  3416: 'end period',
#  1531: 'parent of this hybrid, breed, or cultivar',
#  636: 'route of administration',
#  3261: 'anatomical branch of',
#  210: 'party chief representative',
#  2546: 'sidekick of',
#  5059: 'modified version of',
#  1060: 'pathogen transmission process',
#  566: 'basionym',
#  5707: 'work sampled',
#  1536: 'immediate cause of',
#  4545: 'sexually homologous with',
#  4147: 'conjugate acid',
#  3310: 'muscle action',
#  3496: 'teams classification by points',
#  2715: 'elected in',
#  2629: 'BBFC rating',
#  2739: 'typeface/font used',
#  1595: 'charge',
#  1591: 'defendant',
#  3014: 'laws applied',
#  5132: 'suggests the existence of',
#  2959: 'permanent duplicated item',
#  3158: 'enclosure',
#  2545: 'bowling style',
#  2976: 'patronym or matronym for this name',
#  1704: 'is pollinator of',
#  1703: 'is pollinated by',
#  1398: 'structure replaces',
#  2239: 'first aid measures',
#  1574: 'exemplar of',
#  3161: 'has grammatical mood',
#  1372: 'binding of software library',
#  6186: 'category for eponymous categories',
#  612: 'mother house',
#  1594: 'judge',
#  642: 'of',
#  4324: 'combination classification',
#  5832: 'political coalition',
#  5021: 'test taken',
#  811: 'academic minor',
#  3349: 'designed to carry',
#  3025: 'open days',
#  3094: 'develops from',
#  1211: 'fuel system',
#  1078: 'valvetrain configuration',
#  2502: 'classification of race',
#  4622: 'trophy awarded',
#  2157: 'lithography',
#  7078: 'typing discipline',
#  4185: 'iconographic symbol',
#  6942: 'animator',
#  1546: 'motto',
#  1817: 'addressee',
#  1878: 'Vox-ATypI classification',
#  751: 'introduced feature',
#  4387: 'update method',
#  1429: 'has pet',
#  4777: 'has boundary',
#  756: 'removed feature',
#  6532: 'has phenotype',
#  3262: 'has anatomical branch',
#  4379: 'youth wing',
#  5588: 'invasive to',
#  3019: 'railway signalling system',
#  925: 'presynaptic connection',
#  1951: 'investor',
#  4322: 'best sprinter classification',
#  546: 'docking port',
#  5998: 'distributary',
#  5131: 'possible medical findings',
#  1445: 'fictional universe described in',
#  816: 'decays to',
#  2675: 'reply to',
#  5136: 'less than',
#  2822: 'by-product of',
#  4688: 'geomorphological unit',
#  3275: 'storyboard artist',
#  1057: 'chromosome',
#  3437: 'people or cargo transported',
#  5009: 'complies with',
#  2838: 'professional name (Japan)',
#  817: 'decay mode',
#  459: 'determination method',
#  4006: 'overrules',
#  4934: 'calculated from',
#  2238: 'official symbol',
#  1571: 'codomain',
#  1851: 'input set',
#  6118: 'season ends',
#  768: 'electoral district',
#  2820: 'cardinality of this set',
#  702: 'encoded by',
#  3493: 'legal status (medicine)',
#  1639: 'pendant of',
#  6193: 'ratified by',
#  682: 'biological process',
#  681: 'cell component',
#  680: 'molecular function',
#  3148: 'repeals',
#  6195: 'funding scheme',
#  2825: 'via',
#  654: 'direction relative to location',
#  1534: 'end cause',
#  5422: 'has decorative pattern',
#  545: 'torch lit by',
#  543: 'oath made by',
#  3719: 'regulated by',
#  2553: 'in work',
#  6587: 'league system',
#  4044: 'therapeutic area',
#  4608: 'scenographer',
#  1593: 'defender',
#  2318: 'debut participant',
#  3015: 'backup or reserve team or crew',
#  3093: 'recovered by',
#  1013: 'criterion used',
#  6439: 'has lyrics',
#  4624: 'squadron embarked',
#  6569: 'taxa especially protected in area',
#  3985: 'supports programming language',
#  2743: 'this zoological name is coordinate with',
#  2881: 'promoted',
#  3195: 'league points system',
#  928: 'activating neurotransmitter',
#  1537: 'contributing factor of',
#  4952: 'safety classification and labelling',
#  2377: 'MediaWiki hooks used',
#  2872: 'tourist office',
#  6259: 'epoch',
#  4443: 'card network',
#  518: 'applies to part',
#  134: 'has dialect (DEPRECATED)',
#  4805: 'make-up artist',
#  3005: 'valid in place',
#  3037: 'spatial reference system',
#  1887: 'vice-county',
#  5816: 'state of conservation',
#  1425: 'ecoregion (WWF)',
#  5589: 'microstructure',
#  2848: 'Wi-Fi access',
#  6153: 'research site',
#  6962: 'literary motif',
#  2989: 'has grammatical case',
#  6524: 'expression of',
#  688: 'encodes',
#  878: 'avionics',
#  1620: 'plaintiff',
#  795: 'located on linear feature',
#  1393: 'proxy',
#  4774: 'biological phase',
#  538: 'fracturing',
#  971: 'category combines topics',
#  1776: 'circle of',
#  1079: 'launch contractor',
#  6803: 'taxa found at location',
#  4600: 'polymer of',
#  3103: 'has tense',
#  4444: 'reward',
#  3780: 'active ingredient in',
#  2935: 'connector',
#  4224: 'category contains',
#  4424: 'mandates',
#  2445: 'metasubclass of',
#  1340: 'eye color',
#  515: 'phase of matter',
#  6001: 'applies to people',
#  684: 'ortholog',
#  2560: 'GPU',
#  4220: 'order of battle',
#  5522: 'Unicode block',
#  1789: 'chief operating officer',
#  660: 'EC enzyme classification',
#  128: 'regulates (molecular biology)',
#  1910: 'decreased expression in',
#  4968: 'relevant qualification',
#  3190: 'innervates',
#  2821: 'by-product',
#  3781: 'has active ingredient',
#  1706: 'together with',
#  6437: 'day of regular release',
#  4988: 'test method',
#  489: 'currency symbol description',
#  4788: 'storage device',
#  2738: 'disjoint union of',
#  1210: 'supercharger',
#  1201: 'space tug',
#  6718: 'music video',
#  6440: 'maintenance method',
#  6534: 'type of rear suspension',
#  415: 'radio format',
#  3871: 'tributary orientation',
#  5514: 'accredited by',
#  399: 'companion of',
#  1227: 'astronomical filter',
#  5304: 'type locality (biology)',
#  3205: 'patient of',
#  3081: 'damaged',
#  2210: 'relative to',
#  2501: 'results',
#  970: 'neurological function',
#  3643: 'significant environmental impact',
#  5202: 'adapted by',
#  1918: 'altered regulation leads to',
#  1915: 'gene inversion association with',
#  1137: 'fossil found in this unit',
#  1912: 'deletion association with',
#  1916: 'gene substitution association with',
#  1911: 'increased expression in',
#  1914: 'gene insertion association with',
#  1026: 'doctoral thesis',
#  1011: 'excluding',
#  6106: 'uses capitalization for',
#  873: 'phase point',
#  447: 'review score by',
#  694: 'replaced synonym (for nom. nov.)',
#  5130: 'island of location  (DEPRECATED)',
#  4425: 'mtDNA haplogroup',
#  1686: 'for work',
#  1199: 'mode of inheritance',
#  3610: 'fare zone',
#  1779: 'possible creator',
#  5004: 'in opposition to',
#  3592: 'Saros cycle of eclipse',
#  1012: 'including',
#  3364: 'stereoisomer of',
#  3776: 'inhibitor of',
#  1592: 'prosecutor',
#  2365: 'Roman cognomen',
#  6902: 'era name',
#  5196: 'output method',
#  5072: 'presented in',
#  5326: 'publication in which this taxon name was established',
#  3739: 'inflorescence',
#  872: 'printed by',
#  5052: 'supervisory board member',
#  2839: 'gait',
#  7108: 'location of the point of view',
#  5023: 'activity policy in this place',
#  5307: 'display technology',
#  6166: 'quotes work',
#  5444: 'model year',
#  6540: 'multi-channel network',
#  5166: 'established from medical condition',
#  3082: 'destroyed',
#  4292: 'possessed by spirit',
#  3771: 'activator of',
#  1171: 'approximation algorithm',
#  2828: 'corporate officer',
#  2392: 'teaching method',
#  531: 'diplomatic mission sent',
#  4321: 'best combative classification',
#  5323: 'attested in',
#  4543: 'has listed ingredient',
#  5102: 'nature of statement',
#  550: 'chivalric order',
#  4290: 'official app',
#  3902: 'had as last meal',
#  967: 'guest of honor',
#  4844: 'research intervention',
#  2414: 'substrate of',
#  2417: 'stage classification',
#  1660: 'has index case',
#  453: 'character role',
#  1606: 'natural reservoir of',
#  4967: 'prerequisite',
#  3460: 'colonel-in-chief',
#  1913: 'gene duplication association with',
#  5054: 'cabinet',
#  5028: 'sound designer',
#  3447: 'mirrors data from',
#  4954: 'may prevent',
#  1677: 'index case of',
#  3432: 'parent cell line',
#  4353: 'nominated by',
#  2550: 'recording or performance of',
#  3969: 'signed form',
#  2701: 'file format',
#  6241: 'collection creator',
#  7075: 'video game mod of',
#  2319: 'elector',
#  6978: 'middle family name',
#  5030: 'talk show guest',
#  2679: 'author of foreword',
#  4882: 'segmental innervation',
#  1909: 'side effect',
#  7010: 'imprimitur granted by',
#  2817: 'appears in the heritage monument list',
#  6237: 'real estate developer',
#  1999: 'UNESCO language status',
#  7086: 'start grade',
#  7095: 'end grade',
#  1898: 'lowest note',
#  5095: 'fault',
#  1780: 'school of',
#  5278: 'gender inflection of surname',
#  1855: 'Wikidata property example',
#  3433: 'biological variant of',
#  3354: 'positive therapeutic predictor',
#  3359: 'negative prognostic predictor',
#  3356: 'positive diagnostic predictor',
#  3355: 'negative therapeutic predictor',
#  537: 'twinning',
#  2359: 'Roman nomen gentilicium',
#  926: 'postsynaptic connection',
#  4032: 'reviewed by',
#  1170: 'transmitted signal type',
#  301: "category's main topic",
#  2308: 'class',
#  2433: 'gender of a scientific name of a genus',
#  2681: 'is recto of',
#  1897: 'highest note',
#  3026: 'closed on',
#  6224: 'level of description',
#  6533: 'type of front suspension',
#  3440: 'time signature',
#  1558: 'tempo marking',
#  1423: "template's main topic",
#  4452: 'Thibaudeau classification',
#  2876: 'type of unit for this property',
#  1041: 'socket supported',
#  2353: 'statistical unit',
#  3680: 'statement supported by',
#  514: 'interleaves with',
#  6606: 'study or design for',
#  3823: 'Ethnologue language status',
#  5873: 'place of devotion',
#  1775: 'follower of',
#  1956: 'takeoff and landing capability',
#  4100: 'parliamentary group',
#  2587: 'has phoneme',
#  5872: 'perfume note',
#  ...}
